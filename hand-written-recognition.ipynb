# %%
# !wget -q https://git.io/J0fjL -O IAM_Words.zip

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# !unzip -qq IAM_Words.zip

# %%
# !mkdir data

# %%
# !mkdir data/words

# %%
# !tar -xf IAM_Words/words.tgz -C data/words

# %%
# !mv IAM_Words/words.txt data

# %%
# !head -20 data/words.txt
# Out:
# #--- words.txt ---------------------------------------------------------------#
# #
# # iam database word information
# #
# # format: a01-000u-00-00 ok 154 1 408 768 27 51 AT A
# #
# #     a01-000u-00-00  -> word id for line 00 in form a01-000u
# #     ok              -> result of word segmentation
# #                            ok: word was correctly
# #                            er: segmentation of word can be bad
# #
# #     154             -> graylevel to binarize the line containing this word
# #     1               -> number of components for this word
# #     408 768 27 51   -> bounding box around this word in x,y,w,h format
# #     AT              -> the grammatical tag for this word, see the
# #                        file tagset.txt for an explanation
# #     A               -> the transcription for this word
# #
# a01-000u-00-00 ok 154 408 768 27 51 AT A
# a01-000u-00-01 ok 154 507 766 213 48 NN MOVE

# %%
from tensorflow.keras.layers.experimental.preprocessing import StringLookup
from tensorflow import keras

import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import os

tf.get_logger().setLevel('INFO')

# %%
# pass some random seed to numpy and tensorflow
np.random.seed(42)
tf.random.set_seed(42)

# %%
# data splitting
base_path="data"
words_list=[]

words=open(f"{base_path}/words.txt","r").readlines()
for line in words:
  if line[0]=='#':
    continue
  if line.split(" ")[1]!='err':
    words_list.append(line) # store lines when it is not error, and not starts with #

# %%
len(words_list)
# Out:
# 96456

# %%
np.random.shuffle(words_list) # shuffles the words in the list

# %%
# 3 datasets - (train, validation,test)
# ratio of train:validation:test - 90:5:5

split_ids=int(0.9*len(words_list)) # train and test
train_samples=words_list[0:split_ids] # 0:100  
test_samples=words_list[split_ids:] # 100:

val_split_ids=int(0.5*len(test_samples)) # test and validation
validation_samples=test_samples[0:val_split_ids]
test_samples=test_samples[val_split_ids:]

# %%
print(len(words_list)) # len of words list
print(len(train_samples)+len(test_samples)+len(validation_samples))
# Out:
# 96456
# 96456

# %%
print(f"Total Training Samples: {len(train_samples)}")
print(f"Total Validation Samples: {len(validation_samples)}")
print(f"Total Test Samples: {len(test_samples)}")
# Out:
# Total Training Samples: 86810
# Total Validation Samples: 4823
# Total Test Samples: 4823

# %%
base_image_path=os.path.join(base_path,"words") # data/words

# %%
def get_image_paths_and_labels(samples):
  paths=[]
  corrected_samples=[] # labels
  for (i,file_line) in enumerate(samples):
    line_split=file_line.strip() # remove all the whitespaces
    line_split=line_split.split(" ")

    image_name=line_split[0]
    partI=image_name.split("-")[0] # a01
    partII=image_name.split("-")[1] # a01-000U
    image_path=os.path.join(
        base_image_path,partI,partI+'-'+partII,image_name+".png"
    )
    if os.path.getsize(image_path):
      paths.append(image_path)
      corrected_samples.append(file_line.split("\n")[0])

  return paths,corrected_samples

# %%
train_img_paths,train_labels=get_image_paths_and_labels(train_samples)

# %%
val_img_paths,val_labels=get_image_paths_and_labels(validation_samples)

# %%
test_img_paths,test_labels=get_image_paths_and_labels(test_samples)

# %%
# clean the labels - train, val, test

train_labels_cleaned=[]
characters=set() # A
max_len=0

for label in train_labels:
  label=label.split(" ")[-1].strip() # extracting the last word (MOVE)
  for char in label:
    characters.add(char)
  max_len=max(max_len,len(label)) # max length of label
  train_labels_cleaned.append(label)

characters=sorted(list(characters))
print("Max Length:",max_len)
print("Vocab Size:",len(characters))
# Out:
# Max Length: 21
# Vocab Size: 78

# %%
train_labels_cleaned[:10]
# Out:
# ['sure',
#  'he',
#  'during',
#  'of',
#  'booty',
#  'gastronomy',
#  'boy',
#  'The',
#  'and',
#  'in']

# %%
def clean_labels(labels):
  cleaned_labels=[]
  for label in labels:
    label=label.split(" ")[-1].strip()
    cleaned_labels.append(label)
  
  return cleaned_labels

# %%
val_labels_cleaned=clean_labels(val_labels)
test_labels_cleaned=clean_labels(test_labels)

# %%
val_labels_cleaned[:10]
# Out:
# ['able', 'full', '.', 'act', 'you', 'National', '-', 'abyss', 'said', 'in']

# %%
test_labels_cleaned[:10]
# Out:
# ['altered',
#  'Here',
#  "'",
#  'the',
#  'It',
#  'up',
#  'edges',
#  'The',
#  'position',
#  'scratched']

# %%
# Character Vocab

AUTOTUNE=tf.data.AUTOTUNE

# Map chars to integers - encoding
char_to_num=StringLookup(vocabulary=list(characters),mask_token=None)

# Map Integers back to chars - decoding
num_to_char=StringLookup(vocabulary=char_to_num.get_vocabulary(),mask_token=None,invert=True)
# Out:
# 2023-02-05 15:19:19.109405: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-05 15:19:19.218246: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-05 15:19:19.219079: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-02-05 15:19:19.220824: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# ...

# %%
# Resizing Image to Rectangle without adding noise

# OCR - Optical Character Recognition 

def rectangle_free_resize(image,img_size):
  w,h=img_size
  image=tf.image.resize(image,size=(h,w),preserve_aspect_ratio=True)

  # check the amount of padding needed to add
  pad_height=h-tf.shape(image)[0]
  pad_width=w-tf.shape(image)[1]

  # only necessary if you want to do same amount of padding on both sides
  if pad_height%2!=0:
    height=pad_height//2
    pad_height_top=height+1
    pad_height_bottom=height
  else:
    pad_height_top=pad_height_bottom=pad_height//2
  
  # in the similar way, we have to check for width
  if pad_width%2!=0:
    width=pad_width//2
    pad_width_left=width+1
    pad_width_right=width
  else:
    pad_width_left=pad_width_right=pad_width//2
  
  # we have to combine all the paddings
  image=tf.pad(image,paddings=[
    [pad_height_top,pad_height_bottom],
    [pad_width_left,pad_width_right],
    [0,0]    
  ])

  # transpose the image
  image=tf.transpose(image,perm=[1,0,2])
  
  # flip the left to right
  image=tf.image.flip_left_right(image)
  return image

# %%
# Data Pre-Processing Stage

batch_size=64
padding_token=99
image_width=128
image_height=32

# converting your square image into rectange 
def preprocess_image(image_path,img_size=(image_width,image_height)):
  image=tf.io.read_file(image_path) # read the content from file
  image=tf.image.decode_png(image,1) # decode them into pixel values
  image=rectangle_free_resize(image,img_size) # square to rect shape
  image=tf.cast(image,tf.float32)/255.0 # Normalisation
  return image

# convert label into a vector
def vectorize_label(label):
  label=char_to_num(tf.strings.unicode_split(label,input_encoding='UTF-8'))
  length=tf.shape(label)[0]
  pad_amount=max_len-length
  label=tf.pad(label,paddings=[[0,pad_amount]],constant_values=padding_token)
  return label

# process image labels
def process_images_labels(image_path,label):
  image=preprocess_image(image_path)
  label=vectorize_label(label)
  return {"image":image,"label":label}

# prepare the dataset
def prepare_dataset(image_paths,labels):
  dataset=tf.data.Dataset.from_tensor_slices((image_paths,labels)).map(
      process_images_labels,num_parallel_calls=AUTOTUNE
  )
  return dataset.batch(batch_size).cache().prefetch(AUTOTUNE)

# %%
# prepare dataset object

train_ds=prepare_dataset(train_img_paths,train_labels_cleaned)
validation_ds=prepare_dataset(val_img_paths,val_labels_cleaned)
test_ds=prepare_dataset(test_img_paths,test_labels_cleaned)

# %%
import logging
logging.getLogger("tensorflow").setLevel(logging.ERROR)

# %%
# Visualise few samples from dataset - train

for data in train_ds.take(1):
  images,labels=data['image'],data['label']
  _,ax=plt.subplots(4,4,figsize=(15,8)) # creating subplots

  for i in range(16):
    img=images[i]
    img=tf.image.flip_left_right(img)
    img=tf.transpose(img,perm=[1,0,2])
    img=(img*255.0).numpy().clip(0,255).astype(np.uint8)
    img=img[:,:,0] # h,w,channel - 0

    label=labels[i]
    indices=tf.gather(label,tf.where(tf.math.not_equal(label,padding_token)))
    label=tf.strings.reduce_join(num_to_char(indices))
    label=label.numpy().decode('utf-8')

    ax[i//4,i%4].imshow(img,cmap='gray')
    ax[i//4,i%4].set_title(label)
    ax[i//4,i%4].axis("off")

plt.show()
# Out:
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# ...

# %%
# Deep Learning Model Creation - Start from Here

class CTCLayer(keras.layers.Layer):
  def __init__(self,name=None):
    super().__init__(name=name)
    self.loss_fn=keras.backend.ctc_batch_cost
  
  def call(self,y_true,y_pred):
    batch_len=tf.cast(tf.shape(y_true)[0],dtype='int64')
    input_length=tf.cast(tf.shape(y_pred)[1],dtype='int64')
    label_length=tf.cast(tf.shape(y_true)[1],dtype='int64')

    input_length=input_length*tf.ones(shape=(batch_len,1),dtype='int64')
    label_length=label_length * tf.ones(shape=(batch_len,1),dtype='int64')
    loss=self.loss_fn(y_true,y_pred,input_length,label_length)
    self.add_loss(loss)

    return y_pred

# %%
# define the model

def build_model():
  # inputs to the model
  input_img=keras.Input(shape=(image_width,image_height,1),name='image')
  labels=keras.layers.Input(name='label',shape=(None,))

  # First Conv Block
  x=keras.layers.Conv2D(
      32,
      (3,3),
      activation='relu',
      kernel_initializer='he_normal',
      padding='same',
      name='Conv1'
  )(input_img)

  # Create MaxPooling Layer
  x=keras.layers.MaxPooling2D((2,2),name='pool1')(x)

  # Second Conv Block
  x=keras.layers.Conv2D(
      64,
      (3,3),
      activation='relu',
      kernel_initializer='he_normal',
      padding='same',
      name='Conv2'
  )(x)

  x=keras.layers.MaxPooling2D((2,2),name='pool2')(x)

  # down sample the feature maps
  new_shape=((image_width//4),(image_height//4)*64)
  x=keras.layers.Reshape(target_shape=new_shape,name='reshape')(x)
  x=keras.layers.Dense(64,activation='relu',name='dense1')(x)
  x=keras.layers.Dropout(0.2)(x)

  # Create RNN - LSTM
  x=keras.layers.Bidirectional(
      keras.layers.LSTM(128,return_sequences=True,dropout=0.25)
  )(x)

  x=keras.layers.Bidirectional(
      keras.layers.LSTM(64,return_sequences=True,dropout=0.25)
  )(x)

  x=keras.layers.Dense(
      len(char_to_num.get_vocabulary()) + 2, activation='softmax',name='dense2'
  )(x)

  # Add CTC Layer for calculating CTC Loss
  output=CTCLayer(name='ctc_loss')(labels,x)

  # define the model
  model=keras.models.Model(
      inputs=[input_img,labels],outputs=output,name='handwriting_recognizer'
  )

  # optimizer
  opt=keras.optimizers.Adam()

  # compile the model
  model.compile(optimizer=opt)
  return model

# %%
model=build_model()
model.summary()
# Out:
# Model: "handwriting_recognizer"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# image (InputLayer)              [(None, 128, 32, 1)] 0
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 128, 32, 32)  320         image[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 64, 16, 32)   0           Conv1[0][0]
# __________________________________________________________________________________________________
# Conv2 (Conv2D)                  (None, 64, 16, 64)   18496       pool1[0][0]
# __________________________________________________________________________________________________
# pool2 (MaxPooling2D)            (None, 32, 8, 64)    0           Conv2[0][0]
# ...

# %%
# seperate validation images and labels

validation_images=[]
validation_labels=[]

for batch in validation_ds:
  validation_images.append(batch['image'])
  validation_labels.append(batch['label'])
# Out:
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# ...

# %%
# create a evaluation metric
def calculate_edit_distance(labels,predictions):
  # get a single batch and convert its labels to sparse vectors
  sparse_labels=tf.cast(tf.sparse.from_dense(labels),dtype=tf.int64)

  # Make predictions and convert them into sparse tensors
  input_len=np.ones(predictions.shape[0])*predictions.shape[1]
  predictions_decoded=keras.backend.ctc_decode(
      predictions,input_length=input_len,greedy=True
  )[0][0][:,:max_len]
  sparse_predictions=tf.cast(
      tf.sparse.from_dense(predictions_decoded),dtype=tf.int64
  )

  # compute the edit distance
  edit_distances=tf.edit_distance(
      sparse_predictions,sparse_labels,normalize=False
  )
  return tf.reduce_mean(edit_distances)

# %%
# create a class for callback of edit distance

class EditDistanceCallback(keras.callbacks.Callback):
  def __init__(self,pred_model):
    super().__init__()
    self.prediction_model=pred_model
  
  def on_epoch_end(self,epoch,logs=None):
    edit_distances=[]
    for i in range(len(validation_images)):
      labels=validation_labels[i]
      predictions=self.prediction_model.predict(validation_images[i])
      edit_distances.append(calculate_edit_distance(labels,predictions).numpy())
      print(f"Mean Edit Distance for epoch {epoch+1}:{np.mean(edit_distances):.4f}")

# %%
# Training Stage

epochs=50
model=build_model()
prediction_model=keras.models.Model(
    model.get_layer(name='image').input,model.get_layer(name='dense2').output
)

edit_distance_callback=EditDistanceCallback(prediction_model)

history=model.fit(
    train_ds,
    validation_data=validation_ds,
    epochs=epochs,
    callbacks=[edit_distance_callback]
)
# Out:
# Epoch 1/50
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# ...

# %%
# Decode the network
def decode_batch_predictions(pred):
  input_len=np.ones(pred.shape[0])*pred.shape[1]
  results=keras.backend.ctc_decode(pred,input_length=input_len,greedy=True)[0][0][:,:max_len]
  # iterate over results
  output_text=[]
  for res in results:
    res=tf.gather(res,tf.where(tf.math.not_equal(res,-1)))
    res=tf.strings.reduce_join(num_to_char(res)).numpy().decode('utf-8')
    output_text.append(res)
  return output_text

# %%
# check results
for batch in test_ds.take(2):
  batch_images=batch['image']
  _,ax=plt.subplots(4,4,figsize=(15,8))

  preds=prediction_model.predict(batch_images)
  pred_texts=decode_batch_predictions(preds)

  for i in range(16):
    img=batch_images[i]
    img=tf.image.flip_left_right(img)
    img=tf.transpose(img,perm=[1,0,2])
    img=(img*255.0).numpy().clip(0,255).astype(np.uint8)
    img=img[:,:,0]

    title=f"Prediction: {pred_texts[i]}"
    ax[i//4, i%4].imshow(img,cmap='gray')
    ax[i//4,i%4].set_title(title)
    ax[i//4,i%4].axis("off")
plt.show()
# Out:
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# Cleanup called...
# ...
